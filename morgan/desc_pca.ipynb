# %%
#DESCRIPTOR CACLULATION

# %%
import pandas as pd
from rdkit import Chem
from rdkit.Chem import Descriptors

# Read the CSV file containing SMILES
filepath1 = '/home/ritesh/Desktop/MOLECULES/morgan/finaldatasetman.csv'

# %%
import pandas as pd
from rdkit import Chem
from rdkit.Chem import Descriptors

# Read the CSV file containing SMILES
filepath1 = '/home/ritesh/Desktop/MOLECULES/morgan/finaldatasetman.csv'
data = pd.read_csv(filepath1)

# Create an empty list to store descriptor dictionaries
descriptor_list = []

# Iterate over each row (SMILES) in the input data frame
for index, row in data.iterrows():
    smiles = row['SMILES']
    
    # Convert SMILES string to RDKit molecule object
    mol = Chem.MolFromSmiles(smiles)
    
    # Calculate all available 1D descriptors for the molecule and add them to descriptor dictionary
    descriptor_dict = {'SMILES': smiles}
    
    for desc_name, desc_func in Descriptors.descList:
        descriptor_dict[desc_name] = desc_func(mol)

    # Append descriptor dictionary to list 
    descriptor_list.append(descriptor_dict)

# Create DataFrame from list of dictionaries 
descriptors_df = pd.DataFrame.from_records(descriptor_list)

# Save calculated descriptors to a new CSV file
descriptors_df.to_csv('output.csv', index=False)

# %%
import pandas as pd
from rdkit import Chem
from rdkit.Chem import Descriptors

# Read input CSV file containing SMILES strings
filepath1 = '/home/ritesh/Desktop/MOLECULES/morgan/finaldatasetman.csv'
data = pd.read_csv(filepath1)

# Calculate descriptors for each SMILES string
# Calculate descriptors for each SMILES string
descriptors = []
for smiles in data["SMILES"]:
    mol = Chem.MolFromSmiles(smiles)
    descriptor_values = [
        Descriptors.MaxEStateIndex(mol),
        Descriptors.MinEStateIndex(mol),
        Descriptors.MaxAbsEStateIndex(mol),
        Descriptors.MinAbsEStateIndex(mol),
        Descriptors.qed(mol),
        Descriptors.MolWt(mol),
        Descriptors.HeavyAtomMolWt(mol),
        Descriptors.ExactMolWt(mol),
        Descriptors.NumValenceElectrons(mol),
        Descriptors.NumRadicalElectrons(mol),
        Descriptors.MaxPartialCharge(mol),
        Descriptors.MinPartialCharge(mol),
        Descriptors.MaxAbsPartialCharge(mol),
        Descriptors.MinAbsPartialCharge(mol),
        Descriptors.FpDensityMorgan1(mol),
        Descriptors.FpDensityMorgan2(mol),
        Descriptors.FpDensityMorgan3(mol),
        Descriptors.BalabanJ(mol),
        Descriptors.BertzCT(mol),
        Descriptors.Chi0(mol),
        Descriptors.Chi0n(mol),
        Descriptors.Chi0v(mol),
        Descriptors.Chi1(mol),
        Descriptors.Chi1n(mol),
        Descriptors.Chi1v(mol),
        Descriptors.Chi2n(mol),
        Descriptors.Chi2v(mol),
        Descriptors.Chi3n(mol),
        Descriptors.Chi3v(mol),
        Descriptors.Chi4n(mol),
        Descriptors.Chi4v(mol),
        Descriptors.HallKierAlpha(mol),
        Descriptors.Ipc(mol),
        Descriptors.Kappa1(mol),
        Descriptors.Kappa2(mol),
        Descriptors.Kappa3(mol),
        Descriptors.LabuteASA(mol),
        Descriptors.PEOE_VSA1(mol),
        Descriptors.PEOE_VSA10(mol),
        Descriptors.PEOE_VSA11(mol),
        Descriptors.PEOE_VSA12(mol),
        Descriptors.PEOE_VSA13(mol),
        Descriptors.PEOE_VSA14(mol),
        Descriptors.PEOE_VSA2(mol),
        Descriptors.PEOE_VSA3(mol),
        Descriptors.PEOE_VSA4(mol),
        Descriptors.PEOE_VSA5(mol),
        Descriptors.PEOE_VSA6(mol),
        Descriptors.PEOE_VSA7(mol),
        Descriptors.PEOE_VSA8(mol),
        Descriptors.PEOE_VSA9(mol),
        Descriptors.SMR_VSA1(mol),
        Descriptors.SMR_VSA10(mol),
        Descriptors.SMR_VSA2(mol),
        Descriptors.SMR_VSA3(mol),
        Descriptors.SMR_VSA4(mol),
        Descriptors.SMR_VSA5(mol),
        Descriptors.SMR_VSA6(mol),
        Descriptors.SMR_VSA7(mol),
        Descriptors.SMR_VSA8(mol),
        Descriptors.SMR_VSA9(mol),
        Descriptors.SlogP_VSA1(mol),
        Descriptors.SlogP_VSA10(mol),
        Descriptors.SlogP_VSA11(mol),
        Descriptors.SlogP_VSA12(mol),
        Descriptors.SlogP_VSA2(mol),
        Descriptors.SlogP_VSA3(mol),
        Descriptors.SlogP_VSA4(mol),
        Descriptors.SlogP_VSA5(mol),
        Descriptors.SlogP_VSA6(mol),
        Descriptors.SlogP_VSA7(mol),
        Descriptors.SlogP_VSA8(mol),
        Descriptors.SlogP_VSA9(mol),
        Descriptors.TPSA(mol),
        Descriptors.EState_VSA1(mol),
        Descriptors.EState_VSA10(mol),
        Descriptors.EState_VSA11(mol),
        Descriptors.EState_VSA2(mol),
        Descriptors.EState_VSA3(mol),
        Descriptors.EState_VSA4(mol),
        Descriptors.EState_VSA5(mol),
        Descriptors.EState_VSA6(mol),
        Descriptors.EState_VSA7(mol),
        Descriptors.EState_VSA8(mol),
        Descriptors.EState_VSA9(mol),
        Descriptors.VSA_EState1(mol),
        Descriptors.VSA_EState10(mol),
        Descriptors.VSA_EState2(mol),
        Descriptors.VSA_EState3(mol),
        Descriptors.VSA_EState4(mol),
        Descriptors.VSA_EState5(mol),
        Descriptors.VSA_EState6(mol),
        Descriptors.VSA_EState7(mol),
        Descriptors.VSA_EState8(mol),
        Descriptors.VSA_EState9(mol),
        Descriptors.FractionCSP3(mol),
        Descriptors.HeavyAtomCount(mol),
        Descriptors.NHOHCount(mol),
        Descriptors.NOCount(mol),
        Descriptors.NumAliphaticCarbocycles(mol),
        Descriptors.NumAliphaticHeterocycles(mol),
        Descriptors.NumAliphaticRings(mol),
        Descriptors.NumAromaticCarbocycles(mol),
        Descriptors.NumAromaticHeterocycles(mol),
        Descriptors.NumAromaticRings(mol),
        Descriptors.NumHAcceptors(mol),
        Descriptors.NumHDonors(mol),
        Descriptors.NumHeteroatoms(mol),
        Descriptors.NumRotatableBonds(mol),
        Descriptors.NumSaturatedCarbocycles(mol),
        Descriptors.NumSaturatedHeterocycles(mol),
        Descriptors.NumSaturatedRings(mol),
        Descriptors.RingCount(mol),
        Descriptors.MolLogP(mol),
        Descriptors.MolMR(mol)
    ]
    descriptors.append(descriptor_values)


# Create a DataFrame to store the calculated descriptors and SMILES strings
descriptor_names = [
    "MaxEStateIndex", "MinEStateIndex", "MaxAbsEStateIndex", "MinAbsEStateIndex",
    "qed", "MolecularWeight", "HeavyAtomMolecularWeight", "ExactMolecularWeight",
    "NumValenceElectrons", "NumRadicalElectrons", "MaxPartialCharge", "MinPartialCharge",
    "MaxAbsPartialCharge", "MinAbsPartialCharge", "FpDensityMorgan1", "FpDensityMorgan2",
    "FpDensityMorgan3", "BalabanJ", "BertzCT", "Chi0", "Chi0n", "Chi0v", "Chi1", "Chi1n",
    "Chi1v", "Chi2n", "Chi2v", "Chi3n", "Chi3v", "Chi4n", "Chi4v", "HallKierAlpha", "Ipc",
    "Kappa1", "Kappa2", "Kappa3", "LabuteASA", "PEOE_VSA1", "PEOE_VSA10", "PEOE_VSA11",
    "PEOE_VSA12", "PEOE_VSA13", "PEOE_VSA14", "PEOE_VSA2", "PEOE_VSA3", "PEOE_VSA4",
    "PEOE_VSA5", "PEOE_VSA6", "PEOE_VSA7", "PEOE_VSA8", "PEOE_VSA9", "SMR_VSA1", "SMR_VSA10",
    "SMR_VSA2", "SMR_VSA3", "SMR_VSA4", "SMR_VSA5", "SMR_VSA6", "SMR_VSA7", "SMR_VSA8",
    "SMR_VSA9", "SlogP_VSA1", "SlogP_VSA10", "SlogP_VSA11", "SlogP_VSA12", "SlogP_VSA2",
    "SlogP_VSA3", "SlogP_VSA4", "SlogP_VSA5", "SlogP_VSA6", "SlogP_VSA7", "SlogP_VSA8",
    "SlogP_VSA9", "TPSA", "EState_VSA1", "EState_VSA10", "EState_VSA11", "EState_VSA2",
    "EState_VSA3", "EState_VSA4", "EState_VSA5", "EState_VSA6", "EState_VSA7", "EState_VSA8",
    "EState_VSA9", "VSA_EState1", "VSA_EState10", "VSA_EState2", "VSA_EState3", "VSA_EState4",
    "VSA_EState5", "VSA_EState6", "VSA_EState7", "VSA_EState8", "VSA_EState9", "FractionCSP3",
    "HeavyAtomCount", "NHOHCount", "NOCount", "NumAliphaticCarbocycles",
    "NumAliphaticHeterocycles", "NumAliphaticRings", "NumAromaticCarbocycles",
    "NumAromaticHeterocycles", "NumAromaticRings", "NumHAcceptors", "NumHDonors",
    "NumHeteroatoms", "NumRotatableBonds", "NumSaturatedCarbocycles",
    "NumSaturatedHeterocycles", "NumSaturatedRings", "RingCount", "MolLogP", "MolMR"
]
descriptor_df = pd.DataFrame(descriptors, columns=descriptor_names)
result_df = pd.concat([data["SMILES"], descriptor_df], axis=1)

# Save the results to a new CSV file
output_file = "testddf.csv"
result_df.to_csv(output_file, index=False)

# %%
import pandas as pd

# Read the first CSV file with SMILES and 1D descriptors
csv_file_1d = "/home/ritesh/Desktop/MOLECULES/morgan/output.csv"
df_1d = pd.read_csv(csv_file_1d)

# Read the second CSV file with SMILES and 2D descriptors
csv_file_2d = "/home/ritesh/Desktop/MOLECULES/morgan/testddf.csv"
df_2d = pd.read_csv(csv_file_2d)

# Merge the two dataframes based on SMILES column and ignore duplicate columns
merged_df = pd.merge(df_1d, df_2d, on="SMILES", how="inner", suffixes=('_1D', '_2D'))

# Save the merged dataframe to a new CSV file
output_file = "1d2d_desc.csv"
merged_df.to_csv(output_file, index=False)

# %%
import pandas as pd
from rdkit import Chem
from rdkit.Chem import Descriptors3D
from rdkit.Chem import AllChem

# Read input CSV file containing SMILES strings
input_file = '/home/ritesh/Desktop/MOLECULES/morgan/finaldatasetman.csv'
df = pd.read_csv(input_file)

# Initialize lists to store the descriptors
descriptors = {
    'RadiusOfGyration': [],
    'InertialShapeFactor': [],
    'Eccentricity': [],
    'Asphericity': [],
    'SpherocityIndex': [],
    'PrincipalMomentsOfInertia1': [],
    'PrincipalMomentsOfInertia2': [],
    'PrincipalMomentsOfInertia3': [],
    'NormalizedPrincipalMomentsRatio1': [],
    'NormalizedPrincipalMomentsRatio2': []
}

# For each molecule in the DataFrame
for index, row in df.iterrows():
    smiles = row['SMILES']  # Getting the SMILES string from the "SMILES" column for the current row

    # Create a molecule from the SMILES string
    molecule = Chem.MolFromSmiles(smiles)

    # Add hydrogens to the molecule
    molecule = Chem.AddHs(molecule)

    # Generate a 3D conformation using the ETKDG method
    AllChem.EmbedMolecule(molecule, AllChem.ETKDG())

    # Compute the descriptors
    descriptors['RadiusOfGyration'].append(Descriptors3D.RadiusOfGyration(molecule))
    descriptors['InertialShapeFactor'].append(Descriptors3D.InertialShapeFactor(molecule))
    descriptors['Eccentricity'].append(Descriptors3D.Eccentricity(molecule))
    descriptors['Asphericity'].append(Descriptors3D.Asphericity(molecule))
    descriptors['SpherocityIndex'].append(Descriptors3D.SpherocityIndex(molecule))
    descriptors['PrincipalMomentsOfInertia1'].append(Descriptors3D.PMI1(molecule))
    descriptors['PrincipalMomentsOfInertia2'].append(Descriptors3D.PMI2(molecule))
    descriptors['PrincipalMomentsOfInertia3'].append(Descriptors3D.PMI3(molecule))
    descriptors['NormalizedPrincipalMomentsRatio1'].append(Descriptors3D.NPR1(molecule))
    descriptors['NormalizedPrincipalMomentsRatio2'].append(Descriptors3D.NPR2(molecule))

# Create a DataFrame to store the descriptors
descriptor_df = pd.DataFrame(descriptors)

# Concatenate the SMILES column and descriptor DataFrame
output_df = pd.concat([df['SMILES'], descriptor_df], axis=1)

# Save the updated DataFrame to a CSV file
output_file = '3D_DESC.csv'
output_df.to_csv(output_file, index=False)

# %%
import pandas as pd

# Read the first CSV file with SMILES and 1D descriptors
csv_file_1d = "/home/ritesh/Desktop/MOLECULES/morgan/1d2d_desc.csv"
df_1d = pd.read_csv(csv_file_1d)

# Read the second CSV file with SMILES and 2D descriptors
csv_file_2d = "/home/ritesh/Desktop/MOLECULES/morgan/3D_DESC.csv"
df_2d = pd.read_csv(csv_file_2d)

# Merge the two dataframes based on SMILES column and ignore duplicate columns
merged_df = pd.merge(df_1d, df_2d, on="SMILES", how="inner", suffixes=('_1D', '_2D'))

# Save the merged dataframe to a new CSV file
output_file = "ALLDESCRIPTORS.csv"
merged_df.to_csv(output_file, index=False)

# %%
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# Read the CSV file into a DataFrame
input_file = "/home/ritesh/Desktop/MOLECULES/morgan/ALLDESCRIPTORS.csv"
df = pd.read_csv(input_file)

# Separate SMILES column from descriptor columns
smiles = df['SMILES']
descriptors = df.drop('SMILES', axis=1)

# Normalize the descriptor columns
scaler = StandardScaler()
descriptors_normalized = scaler.fit_transform(descriptors)

# Perform PCA
n_components = 40  # Specify the desired number of components
pca = PCA(n_components=n_components)
pca_results = pca.fit_transform(descriptors_normalized)

# Explained variance ratio
explained_variance_ratio = pca.explained_variance_ratio_

# Print explained variance ratio
for i, ratio in enumerate(explained_variance_ratio):
    print(f"Explained Variance Ratio for PC{i+1}: {ratio}")
print(f"Percentage of Variance Retained with {47} components: {sum(explained_variance_ratio[:47]) * 100:.2f}%")

# Create a new DataFrame with PCA results
pca_columns = [f"PC{i+1}" for i in range(n_components)]
pca_df = pd.DataFrame(data=pca_results, columns=pca_columns)

# Add the SMILES column to the PCA DataFrame
pca_df['SMILES'] = smiles

# Save the PCA results to a CSV file
output_file = "pca_results.csv"
pca_df.to_csv(output_file, index=False)
# Out:
# Explained Variance Ratio for PC1: 0.23376332656076104
# Explained Variance Ratio for PC2: 0.11856045974014193
# Explained Variance Ratio for PC3: 0.11013660991419158
# Explained Variance Ratio for PC4: 0.07342453795240272
# Explained Variance Ratio for PC5: 0.06143806031226038
# Explained Variance Ratio for PC6: 0.04811668207159402
# Explained Variance Ratio for PC7: 0.044977280239093045
# Explained Variance Ratio for PC8: 0.03444064276758061
# Explained Variance Ratio for PC9: 0.03000761934308288
# Explained Variance Ratio for PC10: 0.027768338350963005
# Explained Variance Ratio for PC11: 0.02460018139122922
# Explained Variance Ratio for PC12: 0.020821454536008338
# Explained Variance Ratio for PC13: 0.01977810533302289
# Explained Variance Ratio for PC14: 0.01859820118368153
# Explained Variance Ratio for PC15: 0.016267425100278454
# Explained Variance Ratio for PC16: 0.01363826878688359
# Explained Variance Ratio for PC17: 0.012404470152131062
# Explained Variance Ratio for PC18: 0.010673080629703624
# Explained Variance Ratio for PC19: 0.010331609638330566
# Explained Variance Ratio for PC20: 0.008774576308775293
# Explained Variance Ratio for PC21: 0.007506603658049943
# Explained Variance Ratio for PC22: 0.007225022476517391
# Explained Variance Ratio for PC23: 0.005823419502944831
# Explained Variance Ratio for PC24: 0.005385558599812207
# Explained Variance Ratio for PC25: 0.004490556999791083
# Explained Variance Ratio for PC26: 0.004303525229692677
# Explained Variance Ratio for PC27: 0.003546443857455578
# Explained Variance Ratio for PC28: 0.003211157012985616
# Explained Variance Ratio for PC29: 0.002687768624845577
# Explained Variance Ratio for PC30: 0.002614946829848211
# Explained Variance Ratio for PC31: 0.002204242356914825
# Explained Variance Ratio for PC32: 0.0019112497019058315
# Explained Variance Ratio for PC33: 0.0016268760486279389
# Explained Variance Ratio for PC34: 0.0014016563388021465
# Explained Variance Ratio for PC35: 0.0011861147403988163
# Explained Variance Ratio for PC36: 0.0011042837969173895
# Explained Variance Ratio for PC37: 0.0009806936634721127
# Explained Variance Ratio for PC38: 0.0007077934288714786
# Explained Variance Ratio for PC39: 0.00060341054594515
# Explained Variance Ratio for PC40: 0.0005420205997063216
# Percentage of Variance Retained with 47 components: 99.76%

# %%
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# %%
# Create a scatter plot of the PCA results
plt.scatter(pca_results[:, 0], pca_results[:, 1])
plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")
plt.title("PCA Scatter Plot")
plt.show()

# %%
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer

# %%
# Read the CSV file into a DataFrame
input_file = "/home/ritesh/Desktop/MOLECULES/morgan/ALLDESCRIPTORS.csv"
df = pd.read_csv(input_file)

# Separate SMILES column from descriptor columns
smiles = df['SMILES']
descriptors = df.drop('SMILES', axis=1)

# Normalize the descriptor columns
scaler = StandardScaler()
descriptors_normalized = scaler.fit_transform(descriptors)

# Perform PCA
n_components = 40  # Specify the desired number of components
pca = PCA(n_components=n_components)
pca_results = pca.fit_transform(descriptors_normalized)

# Create a DataFrame for the PCA results
pca_df2 = pd.DataFrame(data=pca_results, columns=[f"PC{i+1}" for i in range(n_components)])

# Calculate the correlation between the principal components and the original variables
correlation_df = descriptors.join(pca_df2).corr().iloc[:-n_components, -n_components:]

# Print the correlation matrix
print("Correlation Matrix:")
print(correlation_df)
# Out:
# Correlation Matrix:
#                                        PC1       PC2       PC3       PC4  \
# MaxEStateIndex_1D                 0.485926 -0.402629 -0.417304  0.042456
# MinEStateIndex_1D                -0.259870  0.565407  0.608656 -0.182803
# MaxAbsEStateIndex_1D              0.485926 -0.402629 -0.417304  0.042456
# MinAbsEStateIndex_1D             -0.501884  0.327261  0.420626 -0.024877
# qed_1D                            0.480738  0.246736 -0.211048  0.142340
# ...                                    ...       ...       ...       ...
# PrincipalMomentsOfInertia1        0.886216  0.229227 -0.063466  0.018711
# PrincipalMomentsOfInertia2        0.842643 -0.268388  0.118755 -0.245404
# PrincipalMomentsOfInertia3        0.880521 -0.197091  0.073703 -0.263000
# NormalizedPrincipalMomentsRatio1 -0.299552  0.433391 -0.286577  0.484512
# NormalizedPrincipalMomentsRatio2  0.304810 -0.518225  0.402887 -0.229850
#
#                                        PC5       PC6       PC7       PC8  \
# MaxEStateIndex_1D                 0.267481 -0.354591 -0.255739  0.113461
# MinEStateIndex_1D                -0.017220 -0.060309  0.268719 -0.122869
# MaxAbsEStateIndex_1D              0.267481 -0.354591 -0.255739  0.113461
# MinAbsEStateIndex_1D             -0.027958  0.261395  0.315685  0.096858
# qed_1D                           -0.362983  0.261912 -0.300162  0.205527
# ...                                    ...       ...       ...       ...
# PrincipalMomentsOfInertia1       -0.124976  0.101786 -0.030811 -0.035277
# PrincipalMomentsOfInertia2        0.010073  0.058660  0.127837  0.019736
# PrincipalMomentsOfInertia3        0.007602  0.075395  0.108307 -0.010654
# NormalizedPrincipalMomentsRatio1 -0.206450  0.023373 -0.055058 -0.134462
# NormalizedPrincipalMomentsRatio2  0.025752  0.017383  0.024606  0.190999
#
#                                        PC9      PC10  ...      PC31      PC32  \
# MaxEStateIndex_1D                -0.099518 -0.194271  ...  0.040135 -0.002285
# MinEStateIndex_1D                 0.094349 -0.159030  ...  0.000559 -0.023307
# MaxAbsEStateIndex_1D             -0.099518 -0.194271  ...  0.040135 -0.002285
# MinAbsEStateIndex_1D              0.206679  0.039685  ... -0.018796 -0.039226
# qed_1D                           -0.095200  0.250120  ... -0.019013  0.035094
# ...                                    ...       ...  ...       ...       ...
# PrincipalMomentsOfInertia1       -0.058362  0.042877  ... -0.073762  0.016452
# PrincipalMomentsOfInertia2        0.135081 -0.043261  ...  0.038228 -0.064414
# PrincipalMomentsOfInertia3        0.109962 -0.038970  ...  0.050581 -0.067584
# NormalizedPrincipalMomentsRatio1  0.077796  0.172748  ... -0.127048  0.068599
# NormalizedPrincipalMomentsRatio2 -0.151581 -0.038740  ... -0.027838  0.022269
#
#                                       PC33      PC34      PC35      PC36  \
# MaxEStateIndex_1D                 0.021181  0.013588 -0.033042 -0.007210
# MinEStateIndex_1D                -0.028010  0.014176  0.034794  0.025165
# MaxAbsEStateIndex_1D              0.021181  0.013588 -0.033042 -0.007210
# MinAbsEStateIndex_1D              0.116097  0.043164  0.048483  0.001289
# qed_1D                           -0.070335  0.100320  0.090150 -0.034178
# ...                                    ...       ...       ...       ...
# PrincipalMomentsOfInertia1       -0.037631  0.007350 -0.039623  0.050218
# PrincipalMomentsOfInertia2        0.003169 -0.053697 -0.002271 -0.029061
# PrincipalMomentsOfInertia3       -0.000127 -0.039865 -0.012994 -0.026868
# NormalizedPrincipalMomentsRatio1 -0.053437  0.012296 -0.029639  0.053844
# NormalizedPrincipalMomentsRatio2 -0.002875 -0.131424  0.069327 -0.037273
#
#                                       PC37      PC38      PC39      PC40
# MaxEStateIndex_1D                -0.007184 -0.033922  0.020248 -0.011768
# MinEStateIndex_1D                -0.004128  0.014002  0.009703  0.001273
# MaxAbsEStateIndex_1D             -0.007184 -0.033922  0.020248 -0.011768
# MinAbsEStateIndex_1D             -0.078384 -0.039430  0.050230 -0.026530
# qed_1D                            0.069891 -0.069353 -0.018691 -0.023530
# ...                                    ...       ...       ...       ...
# PrincipalMomentsOfInertia1        0.059195 -0.021728 -0.036438 -0.025513
# PrincipalMomentsOfInertia2        0.026628  0.084751  0.016979  0.011520
# PrincipalMomentsOfInertia3        0.034620  0.086570  0.007097  0.009170
# NormalizedPrincipalMomentsRatio1  0.039581 -0.000099 -0.003184 -0.035700
# NormalizedPrincipalMomentsRatio2 -0.097978 -0.090266  0.025309  0.034471
#
# [333 rows x 40 columns]

# %%
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# Read the CSV file into a DataFrame
input_file = "/home/ritesh/Desktop/MOLECULES/morgan/ALLDESCRIPTORS.csv"
df = pd.read_csv(input_file)

# Separate SMILES column from descriptor columns
smiles = df['SMILES']
descriptors = df.drop('SMILES', axis=1)

# Normalize the descriptor columns
scaler = StandardScaler()
descriptors_normalized = scaler.fit_transform(descriptors)

# Perform PCA
n_components = descriptors.shape[1]  # Set the number of components to the total number of descriptors
pca = PCA(n_components=n_components)
pca_results = pca.fit_transform(descriptors_normalized)

# Explained variance ratio
explained_variance_ratio = pca.explained_variance_ratio_

# Print explained variance ratio and descriptor names
for i, (ratio, descriptor) in enumerate(zip(explained_variance_ratio, descriptors.columns)):
    print(f"Explained Variance Ratio for {descriptor}: {ratio}")
    print(f"Principal Component Name for {descriptor}: PC{i+1}")

print(f"Percentage of Variance Retained with {n_components} components: {sum(explained_variance_ratio) * 100:.2f}%")

# Create a new DataFrame with PCA results
pca_columns = [f"PC{i+1}" for i in range(n_components)]
pca_df = pd.DataFrame(data=pca_results, columns=pca_columns)

# Add the SMILES column to the PCA DataFrame
pca_df['SMILES'] = smiles

# Save the PCA results to a CSV file
output_file = "pca_results2.csv"
pca_df.to_csv(output_file, index=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 20
#      18 n_components = descriptors.shape[1]  # Set the number of components to the total number of descriptors
#      19 pca = PCA(n_components=n_components)
# ---> 20 pca_results = pca.fit_transform(descriptors_normalized)
#      22 # Explained variance ratio
#      23 explained_variance_ratio = pca.explained_variance_ratio_
#
# File ~/anaconda3/envs/MOLECULES/lib/python3.11/site-packages/sklearn/utils/_set_output.py:140, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     138 @wraps(f)
#     139 def wrapped(self, X, *args, **kwargs):
# --> 140     data_to_wrap = f(self, X, *args, **kwargs)
#     141     if isinstance(data_to_wrap, tuple):
#     142         # only wrap the first output for cross decomposition
#     143         return_tuple = (
#     144             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     145             *data_to_wrap[1:],
#     146         )
#
# File ~/anaconda3/envs/MOLECULES/lib/python3.11/site-packages/sklearn/base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File ~/anaconda3/envs/MOLECULES/lib/python3.11/site-packages/sklearn/decomposition/_pca.py:460, in PCA.fit_transform(self, X, y)
#     437 @_fit_context(prefer_skip_nested_validation=True)
#     438 def fit_transform(self, X, y=None):
#     439     """Fit the model with X and apply the dimensionality reduction on X.
#     440
#     441     Parameters
#    (...)
#     458     C-ordered array, use 'np.ascontiguousarray'.
#     459     """
# --> 460     U, S, Vt = self._fit(X)
#     461     U = U[:, : self.n_components_]
#     463     if self.whiten:
#     464         # X_new = X * V / S * sqrt(n_samples) = U * sqrt(n_samples)
#
# File ~/anaconda3/envs/MOLECULES/lib/python3.11/site-packages/sklearn/decomposition/_pca.py:510, in PCA._fit(self, X)
#     508 # Call different fits for either full or truncated SVD
#     509 if self._fit_svd_solver == "full":
# --> 510     return self._fit_full(X, n_components)
#     511 elif self._fit_svd_solver in ["arpack", "randomized"]:
#     512     return self._fit_truncated(X, n_components, self._fit_svd_solver)
#
# File ~/anaconda3/envs/MOLECULES/lib/python3.11/site-packages/sklearn/decomposition/_pca.py:524, in PCA._fit_full(self, X, n_components)
#     520         raise ValueError(
#     521             "n_components='mle' is only supported if n_samples >= n_features"
#     522         )
#     523 elif not 0 <= n_components <= min(n_samples, n_features):
# --> 524     raise ValueError(
#     525         "n_components=%r must be between 0 and "
#     526         "min(n_samples, n_features)=%r with "
#     527         "svd_solver='full'" % (n_components, min(n_samples, n_features))
#     528     )
#     530 # Center data
#     531 self.mean_ = np.mean(X, axis=0)
#
# ValueError: n_components=333 must be between 0 and min(n_samples, n_features)=73 with svd_solver='full'
